# %% [markdown]
# # Baseline Model
#
# ## Overview
#
# *   Apply BERT Large Cased Model on SQUAD 2.0 Data set
# *   Download the pretrained model and the questions
# *   Set up GCP and TPUS
# *   Train the model
# *   Evaluate results on Dev set.

# %% [markdown]
# ### Step 1: Clone the Repo

# %%
#This will clone the BERT Repo

# !git clone https://github.com/google-research/bert.git
# Out:
# Cloning into 'bert'...
# remote: Enumerating objects: 340, done.
# remote: Total 340 (delta 0), reused 0 (delta 0), pack-reused 340
# Receiving objects: 100% (340/340), 317.20 KiB | 4.12 MiB/s, done.
# Resolving deltas: 100% (185/185), done.

# %%
#The code in the BERT Repo is written in tf 1, and the tf conversion process fails on these files.
#For this reason, it was easiest to revert to tf v1 for the purposes of this notebook

# %tensorflow_version 1.x
import tensorflow
print(tensorflow.__version__)
# Out:
# TensorFlow 1.x selected.
# 1.15.2

# %%
#Make sure were in the right place

# %ls
# Out:
# bert/  sample_data/

# %%
# Move to BERT folder 

# %cd bert
# Out:
# /content/bert

# %% [markdown]
# ### Step 2: Select a model + Download Train/Dev sets

# %% [markdown]
# BERT Pretrained Model List :
#
# *   BERT-Large, Uncased (Whole Word Masking) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   BERT-Large, Cased (Whole Word Masking) : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   BERT-Base, Uncased : 12-layer, 768-hidden, 12-heads, 110M parameters
# *   BERT-Large, Uncased : 24-layer, 1024-hidden, 16-heads, 340M parameters
# *   BERT-Base, Cased: 12-layer, 768-hidden, 12-heads , 110M parameters
# *   BERT-Large, Cased : 24-layer, 1024-hidden, 16-heads, 340M parameters
#
# Based on my EDA, capitalization is important, so I am using the Large Cased model.

# %%
# Download the cased model. 

# !wget https://storage.googleapis.com/bert_models/2018_10_18/cased_L-24_H-1024_A-16.zip
# Out:
# --2020-07-17 23:52:51--  https://storage.googleapis.com/bert_models/2018_10_18/cased_L-24_H-1024_A-16.zip
# Resolving storage.googleapis.com (storage.googleapis.com)... 173.194.74.128, 74.125.124.128, 172.217.212.128, ...
# Connecting to storage.googleapis.com (storage.googleapis.com)|173.194.74.128|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1242178883 (1.2G) [application/zip]
# Saving to: ‘cased_L-24_H-1024_A-16.zip’
#
# cased_L-24_H-1024_A 100%[===================>]   1.16G   156MB/s    in 8.1s
#
# 2020-07-17 23:53:00 (146 MB/s) - ‘cased_L-24_H-1024_A-16.zip’ saved [1242178883/1242178883]

# %%
# Unzip the pretrained model

# !unzip cased_L-24_H-1024_A-16.zip
# Out:
# Archive:  cased_L-24_H-1024_A-16.zip
#    creating: cased_L-24_H-1024_A-16/
#   inflating: cased_L-24_H-1024_A-16/bert_model.ckpt.meta
#   inflating: cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001
#   inflating: cased_L-24_H-1024_A-16/vocab.txt
#   inflating: cased_L-24_H-1024_A-16/bert_model.ckpt.index
#   inflating: cased_L-24_H-1024_A-16/bert_config.json

# %%
#Download the SQUAD train and dev dataset

# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# !wget https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Out:
# --2020-07-17 23:53:23--  https://rajpurkar.github.io/SQuAD-explorer/dataset/train-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 42123633 (40M) [application/json]
# Saving to: ‘train-v2.0.json’
#
# train-v2.0.json     100%[===================>]  40.17M  58.8MB/s    in 0.7s
#
# 2020-07-17 23:53:24 (58.8 MB/s) - ‘train-v2.0.json’ saved [42123633/42123633]
#
# --2020-07-17 23:53:24--  https://rajpurkar.github.io/SQuAD-explorer/dataset/dev-v2.0.json
# Resolving rajpurkar.github.io (rajpurkar.github.io)... 185.199.108.153, 185.199.109.153, 185.199.110.153, ...
# Connecting to rajpurkar.github.io (rajpurkar.github.io)|185.199.108.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4370528 (4.2M) [application/json]
# Saving to: ‘dev-v2.0.json’
#
# dev-v2.0.json       100%[===================>]   4.17M  16.2MB/s    in 0.3s
#
# 2020-07-17 23:53:25 (16.2 MB/s) - ‘dev-v2.0.json’ saved [4370528/4370528]

# %% [markdown]
# ### Step 3: Imports and TPU Setup

# %%
# Imports

import datetime
import json
import os
import time
import pprint
import random
import string
import sys
import tensorflow as tf

# Get TPU Address for training

assert 'COLAB_TPU_ADDR' in os.environ, 'ERROR: Not connected to a TPU runtime; please see the first cell in this notebook for instructions!'
TPU_ADDRESS = 'grpc://' + os.environ['COLAB_TPU_ADDR']
print('TPU address is => ', TPU_ADDRESS)

#Authorize Google and connect.

from google.colab import auth
auth.authenticate_user()
with tf.Session(TPU_ADDRESS) as session:
  print('TPU devices:')
  pprint.pprint(session.list_devices())
  
  # Upload credentials to TPU.
  with open('/content/adc.json', 'r') as f:
    auth_info = json.load(f)
    
  tf.contrib.cloud.configure_gcs(session, credentials=auth_info)
# Out:
# TPU address is =>  grpc://10.19.30.242:8470
# TPU devices:
# [_DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:CPU:0, CPU, -1, 3295030357378495853),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:XLA_CPU:0, XLA_CPU, 17179869184, 3914317039016132569),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:0, TPU, 17179869184, 201647257280353741),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:1, TPU, 17179869184, 11604506492514759225),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:2, TPU, 17179869184, 8970057966084767594),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:3, TPU, 17179869184, 10313378223518499565),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:4, TPU, 17179869184, 16989872891666213779),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:5, TPU, 17179869184, 11658468694366527241),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:6, TPU, 17179869184, 18061371668750479431),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU:7, TPU, 17179869184, 12886066651908822045),
#  _DeviceAttributes(/job:tpu_worker/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 8589934592, 10196067412232481471)]

# %%
# Create variables for Buckets and Outputs for later use. 

BUCKET = 'thaddeussegura_final_project' #@param {type:"string"}
assert BUCKET, '*** Must specify an existing GCS bucket name ***'
output_dir_name = 'self_ensemble_1/' #@param {type:"string"}
BUCKET_NAME = 'gs://{}'.format(BUCKET)
OUTPUT_DIR = 'gs://{}/{}'.format(BUCKET,output_dir_name)
tf.io.gfile.makedirs(OUTPUT_DIR)
print('***** Model output directory: {} *****'.format(OUTPUT_DIR))
# Out:
# ***** Model output directory: gs://thaddeussegura_final_project/self_ensemble_1/ *****

# %%
#Move the model to the google cloud bucket. 

# !gsutil mv /content/bert/cased_L-24_H-1024_A-16 $BUCKET_NAME
# Out:
# Copying file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001 [Content-Type=application/octet-stream]...
# ==> NOTE: You are uploading one or more large file(s), which would run
# significantly faster if you enable parallel composite uploads. This
# feature can be enabled by editing the
# "parallel_composite_upload_threshold" value in your .boto
# configuration file. However, note that if you do this large files will
# be uploaded as `composite objects
# <https://cloud.google.com/storage/docs/composite-objects>`_,which
# means that any user who downloads such objects will need to have a
# compiled crcmod installed (see "gsutil help crcmod"). This is because
# without a compiled crcmod, computing checksums on composite objects is
# so slow that gsutil disables downloads of composite objects.
#
# Removing file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.data-00000-of-00001...
# Copying file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.index [Content-Type=application/octet-stream]...
# Removing file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.index...
# Copying file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.meta [Content-Type=application/octet-stream]...
# Removing file:///content/bert/cased_L-24_H-1024_A-16/bert_model.ckpt.meta...
# Copying file:///content/bert/cased_L-24_H-1024_A-16/bert_config.json [Content-Type=application/json]...
# Removing file:///content/bert/cased_L-24_H-1024_A-16/bert_config.json...
#
# ==> NOTE: You are performing a sequence of gsutil operations that may
# run significantly faster if you instead use gsutil -m cp ... Please
# see the -m section under "gsutil help options" for further information
# about when gsutil -m can be advantageous.
#
# Copying file:///content/bert/cased_L-24_H-1024_A-16/vocab.txt [Content-Type=text/plain]...
# Removing file:///content/bert/cased_L-24_H-1024_A-16/vocab.txt...
#
# Operation completed over 5 objects/1.2 GiB.

# %% [markdown]
# ### Step 4: Train the Model

# %%
'''
Attempt 1:
LR: 3e-5, Epochs:3, Batch:24, Time = 90.3, EM: 77.09, F1: 80.38

Attempt 2:
LR: 3e-5, Epochs:4, Batch:24, Time = 114, EM: 76.6, F1: 80.23

Attempt 3:
LR: 2e-5, Epochs:3, Batch:32, Time = 86, EM: 76.37 , F1: 79.92

Attempt 4:
LR: 5e-5, Epochs:3, Batch:16, Time = 57, EM: 75.24  , F1: 78.93 

OVERTRAIN Model:
LR: 2e-5, Epochs:8, Batch:24, Time = , EM:   , F1:  
'''

#Will train on the training data.
#Will predict on the Dev Set.
#Timing the overall training

start_time = time.time()

# !python run_squad.py \
  --vocab_file=$BUCKET_NAME/cased_L-24_H-1024_A-16/vocab.txt \
  --bert_config_file=$BUCKET_NAME/cased_L-24_H-1024_A-16/bert_config.json \
  --init_checkpoint=$BUCKET_NAME/cased_L-24_H-1024_A-16/bert_model.ckpt \
  --do_train=True \
  --train_file=train-v2.0.json \
  --do_predict=True \
  --predict_file=dev-v2.0.json \
  --train_batch_size=24 \
  --learning_rate=3e-5 \
  --num_train_epochs=4.0 \
  --use_tpu=True \
  --tpu_name=grpc://10.19.30.242:8470 \
  --max_seq_length=384 \
  --doc_stride=128 \
  --save_checkpoints_steps=5000 \
  --version_2_with_negative=True \
  --output_dir=$OUTPUT_DIR \
  --do_lower_case=False

end_time = time.time()
# Out:
# Streaming output truncated to the last 5000 lines.
# I0718 02:01:10.329540 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.347740 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.348136 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.363640 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.363898 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.380717 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.380950 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.397978 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.398242 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.414853 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.415113 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.433790 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.434104 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.449684 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.449928 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.467236 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.467508 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.483518 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.483737 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.501137 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.501384 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.517497 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.517707 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.534810 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.535079 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.551974 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.552278 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.569970 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.570307 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.586725 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.587034 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.603245 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.603496 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.620285 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.620537 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.637731 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.638042 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.655384 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.655651 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.672106 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.672392 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.688985 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.689324 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.705826 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.706095 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.722995 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.723269 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.741629 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.741941 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.757187 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.757449 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.774442 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.774700 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.791191 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.791369 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.807647 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.807807 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.825894 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.826079 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.842207 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.842379 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.860632 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.860849 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.875996 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.876236 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.893247 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.893388 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.910491 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.910627 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.927628 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.927771 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.945412 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.945733 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.962396 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.962687 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.979120 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.979389 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:10.996319 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:10.996582 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.013215 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.013456 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.030374 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.030654 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.047940 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.048231 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.064664 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.064925 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.081641 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.081914 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.099106 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.099347 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.116118 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.116387 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.133580 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.133854 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.150584 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.150861 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.168296 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.168625 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.184620 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.184888 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.202364 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.202685 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.219628 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.219904 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.235726 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.236023 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.253092 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.253371 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.270948 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.271259 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.286747 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.287061 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.303992 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.304299 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.321579 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.321880 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.339975 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.340297 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.355814 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.356123 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.373130 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.373404 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.390307 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.390592 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.407136 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.407425 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.424355 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.424639 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.440837 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.441139 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.459118 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.459378 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.475341 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.475601 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.492777 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.493088 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.509408 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.509689 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.526343 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.526618 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.543878 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.544158 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.560227 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.560492 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Processing example: 3000
# I0718 02:01:11.574114 140649565538176 run_squad.py:1259] Processing example: 3000
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.577684 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.577877 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.594522 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.594769 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.611861 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.612156 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.628771 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.629047 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.646241 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.646529 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.662995 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.663287 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.680132 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.680392 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.697421 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.697686 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.714339 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.714596 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.731493 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.731782 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.748526 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.748792 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.766682 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.766944 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.783354 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.783639 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.800373 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.800629 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.816701 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.816967 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.833661 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.833840 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.852728 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.852961 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.868083 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.868265 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.884577 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.884760 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.902288 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.902437 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.918491 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.918752 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.935649 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.935789 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.952832 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.952980 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.969599 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.969745 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:11.987175 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:11.987331 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.004194 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.004350 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.022134 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.022291 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.038937 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.039137 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.056421 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.056646 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.073029 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.073176 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.089600 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.089749 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.106786 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.106935 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.123967 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.124144 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.141719 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.141875 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.158159 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.158301 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.175495 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.175641 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.192895 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.193075 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.210364 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.210649 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.226966 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.227298 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.246485 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.246749 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.260939 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.261257 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.277861 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.278110 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.295901 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.296171 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.311878 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.312110 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.329291 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.329547 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.346550 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.346798 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.364854 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.365129 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.380568 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.380809 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.397781 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.398048 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.414990 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.415294 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.431963 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.432236 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.448935 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.449198 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.466002 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.466250 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.483787 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.484055 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.500442 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.500650 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.517746 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.517981 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.534604 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.534823 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.552281 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.552585 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.568579 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.568822 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.585539 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.585774 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.603150 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.603397 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.619975 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.620203 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.636889 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.637152 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.654661 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.654890 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.672356 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.672607 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.687814 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.688053 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.705402 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:12.705643 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:12.722222 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# ...
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.807541 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.824208 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.824349 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.841560 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.841707 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.858191 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.858350 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.875137 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.875293 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.892948 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.893128 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.910203 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.910345 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.927201 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.927349 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.944601 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.944757 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.961357 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.961528 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.981079 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.981322 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:30.995427 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:30.995567 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.012622 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.012758 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.030152 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.030348 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.046923 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.047136 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.064002 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.064163 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.080942 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.081111 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.097853 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.097995 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.114922 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.115103 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.131871 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.132005 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.148674 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.148825 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.166319 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.166455 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.183296 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.183438 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.200322 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.200460 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.217681 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.217819 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.234240 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.234384 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.251508 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.251647 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.268450 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.268592 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.286037 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.286261 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.303259 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.303405 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.319700 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.319877 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.337493 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.337631 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.355504 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.355782 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.372729 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.372977 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.390431 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.390684 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.406250 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.406471 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.423297 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.423547 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.439919 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.440156 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.457686 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.457940 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Enqueue next (1) batch(es) of data to infeed.
# I0718 02:01:31.475879 140649565538176 tpu_estimator.py:600] Enqueue next (1) batch(es) of data to infeed.
# INFO:tensorflow:Dequeue next (1) batch(es) of data from outfeed.
# I0718 02:01:31.476177 140649565538176 tpu_estimator.py:604] Dequeue next (1) batch(es) of data from outfeed.
# INFO:tensorflow:Stop infeed thread controller
# I0718 02:01:31.487938 140649565538176 tpu_estimator.py:608] Stop infeed thread controller
# INFO:tensorflow:Shutting down InfeedController thread.
# I0718 02:01:31.488186 140649565538176 tpu_estimator.py:434] Shutting down InfeedController thread.
# INFO:tensorflow:InfeedController received shutdown signal, stopping.
# I0718 02:01:31.488429 140647564695296 tpu_estimator.py:429] InfeedController received shutdown signal, stopping.
# INFO:tensorflow:Infeed thread finished, shutting down.
# I0718 02:01:31.488577 140647564695296 tpu_estimator.py:537] Infeed thread finished, shutting down.
# INFO:tensorflow:infeed marked as finished
# I0718 02:01:31.488784 140649565538176 error_handling.py:101] infeed marked as finished
# INFO:tensorflow:Stop output thread controller
# I0718 02:01:31.488951 140649565538176 tpu_estimator.py:612] Stop output thread controller
# INFO:tensorflow:Shutting down OutfeedController thread.
# I0718 02:01:31.489092 140649565538176 tpu_estimator.py:434] Shutting down OutfeedController thread.
# INFO:tensorflow:OutfeedController received shutdown signal, stopping.
# I0718 02:01:31.489282 140647556302592 tpu_estimator.py:429] OutfeedController received shutdown signal, stopping.
# INFO:tensorflow:Outfeed thread finished, shutting down.
# I0718 02:01:31.489420 140647556302592 tpu_estimator.py:551] Outfeed thread finished, shutting down.
# INFO:tensorflow:outfeed marked as finished
# I0718 02:01:31.489589 140649565538176 error_handling.py:101] outfeed marked as finished
# INFO:tensorflow:Shutdown TPU system.
# I0718 02:01:31.489727 140649565538176 tpu_estimator.py:616] Shutdown TPU system.
# INFO:tensorflow:prediction_loop marked as finished
# I0718 02:01:32.045070 140649565538176 error_handling.py:101] prediction_loop marked as finished
# INFO:tensorflow:prediction_loop marked as finished
# I0718 02:01:32.045364 140649565538176 error_handling.py:101] prediction_loop marked as finished
# INFO:tensorflow:Writing predictions to: gs://thaddeussegura_final_project/self_ensemble_1/predictions.json
# I0718 02:01:32.045580 140649565538176 run_squad.py:745] Writing predictions to: gs://thaddeussegura_final_project/self_ensemble_1/predictions.json
# INFO:tensorflow:Writing nbest to: gs://thaddeussegura_final_project/self_ensemble_1/nbest_predictions.json
# I0718 02:01:32.045686 140649565538176 run_squad.py:746] Writing nbest to: gs://thaddeussegura_final_project/self_ensemble_1/nbest_predictions.json

# %%
total_time = end_time-start_time
print('Minutes to train Large Cased Model (8 epochs):')
print(total_time/60)
# Out:
# Minutes to train Large Cased Model (8 epochs):
# 214.89159316619237

# %% [markdown]
# ### Step 5: Evaluate the Results

# %%
#may need this for the evaluation process
# !git clone https://github.com/white127/SQUAD-2.0-bidaf.git
# Out:
# Cloning into 'SQUAD-2.0-bidaf'...
# remote: Enumerating objects: 125, done.
# remote: Total 125 (delta 0), reused 0 (delta 0), pack-reused 125
# Receiving objects: 100% (125/125), 709.51 KiB | 5.14 MiB/s, done.
# Resolving deltas: 100% (33/33), done.

# %%
#move evaluate-v2.0 into the bert folder

# %mv /content/bert/SQUAD-2.0-bidaf/evaluate-v2.0.py /content/bert/

# %%
# Here I just moved the predictions file manually from the Google Cloud Bucket 
# Into colab.  I will automate this later when I have multiple lines to move.

# %%
# Evaluate the Results 

print("Results for Large, Cased (8 Epochs")
# !python evaluate-v2.0.py dev-v2.0.json preds.json
# Out:
# Results for Large, Cased (8 Epochs
# {
#   "exact": 74.84207866588056,
#   "f1": 78.75671559407992,
#   "total": 11873,
#   "HasAns_exact": 76.73751686909581,
#   "HasAns_f1": 84.57801691101753,
#   "HasAns_total": 5928,
#   "NoAns_exact": 72.95206055508831,
#   "NoAns_f1": 72.95206055508831,
#   "NoAns_total": 5945
# }
